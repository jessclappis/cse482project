# %%
import pandas as pd

data = pd.read_csv("ratings.csv", header=None)
data.head(n=10)
# Out:
#         0               1    2
# 0  107628  Platoon (1986)  4.0
# 1   11237  Platoon (1986)  4.0
# 2  117238  Platoon (1986)  4.0
# 3  118760  Platoon (1986)  4.0
# 4  119677  Platoon (1986)  5.0
# 5  123601  Platoon (1986)  4.5
# 6  124749  Platoon (1986)  4.5
# 7  126121  Platoon (1986)  4.0
# 8   12778  Platoon (1986)  4.0
# 9  129030  Platoon (1986)  3.0

# %%
from surprise import Dataset
from surprise import Reader

# %%
reader = Reader(line_format='user item rating', sep=',')
data = Dataset.load_builtin(name=u'ml-1m')
for i in data.raw_ratings:
    if i[0]=='6':
        print(i[0:3])
# Out:
# ('6', '2406', 5.0)
# ('6', '1101', 4.0)
# ('6', '3717', 4.0)
# ('6', '1030', 4.0)
# ('6', '1688', 5.0)
# ('6', '1035', 5.0)
# ('6', '3578', 4.0)
# ('6', '364', 4.0)
# ('6', '3501', 5.0)
# ('6', '3072', 4.0)
# ('6', '368', 4.0)
# ('6', '296', 2.0)
# ('6', '48', 5.0)
# ('6', '3074', 5.0)
# ('6', '1188', 4.0)
# ('6', '3508', 3.0)
# ('6', '588', 4.0)
# ('6', '1', 4.0)
# ('6', '1043', 4.0)
# ('6', '2858', 1.0)
# ('6', '377', 3.0)
# ('6', '590', 3.0)
# ('6', '595', 4.0)
# ('6', '597', 5.0)
# ('6', '383', 4.0)
# ('6', '2506', 3.0)
# ('6', '3524', 3.0)
# ('6', '1566', 4.0)
# ('6', '1569', 4.0)
# ('6', '2006', 4.0)
# ('6', '2081', 4.0)
# ('6', '2082', 3.0)
# ('6', '3600', 3.0)
# ('6', '3604', 5.0)
# ('6', '2802', 4.0)
# ('6', '3534', 4.0)
# ('6', '3536', 5.0)
# ('6', '1210', 3.0)
# ('6', '3753', 5.0)
# ('6', '3682', 3.0)
# ('6', '2017', 3.0)
# ('6', '3685', 3.0)
# ('6', '3610', 3.0)
# ('6', '1296', 3.0)
# ('6', '838', 4.0)
# ('6', '1007', 3.0)
# ('6', '1947', 5.0)
# ('6', '2966', 5.0)
# ...

# %%
#test=[]
data.raw_ratings
#data.raw_ratings.remove(('1', '661', 3.0, '978302109'))
#for i in data.raw_ratings:
#    if i[0]=='1':
#        test.append(i)
#test
#for i in data.raw_ratings:
#    for y in test:
#        if i==y:
#            data.raw_ratings.remove(i)
#test
#data.raw_ratings
# Out:
# [('1', '1193', 5.0, '978300760'),
#  ('1', '661', 3.0, '978302109'),
#  ('1', '914', 3.0, '978301968'),
#  ('1', '3408', 4.0, '978300275'),
#  ('1', '2355', 5.0, '978824291'),
#  ('1', '1197', 3.0, '978302268'),
#  ('1', '1287', 5.0, '978302039'),
#  ('1', '2804', 5.0, '978300719'),
#  ('1', '594', 4.0, '978302268'),
#  ('1', '919', 4.0, '978301368'),
#  ('1', '595', 5.0, '978824268'),
#  ('1', '938', 4.0, '978301752'),
#  ('1', '2398', 4.0, '978302281'),
#  ('1', '2918', 4.0, '978302124'),
#  ('1', '1035', 5.0, '978301753'),
#  ('1', '2791', 4.0, '978302188'),
#  ('1', '2687', 3.0, '978824268'),
#  ('1', '2018', 4.0, '978301777'),
#  ('1', '3105', 5.0, '978301713'),
#  ('1', '2797', 4.0, '978302039'),
#  ('1', '2321', 3.0, '978302205'),
#  ('1', '720', 3.0, '978300760'),
#  ('1', '1270', 5.0, '978300055'),
#  ('1', '527', 5.0, '978824195'),
#  ('1', '2340', 3.0, '978300103'),
#  ('1', '48', 5.0, '978824351'),
#  ('1', '1097', 4.0, '978301953'),
#  ('1', '1721', 4.0, '978300055'),
# ...

# %%
from surprise import NMF 
algo1 = NMF (n_factors=4, n_epochs=100, random_state=1)
trainSet = data.build_full_trainset()
algo1.fit(trainSet)

# %%
testset = [('1', '1193', 5.0), ('1', '661', 3.0),
('1', '914', 3.0),
('1', '3408', 4.0),
('1', '2355', 5.0),
('1', '1197', 3.0),
('1', '1287', 5.0),
('1', '2804', 5.0),
('1', '594', 4.0),
('1', '919', 4.0),
('1', '595', 5.0),
('1', '938', 4.0),
('1', '2398', 4.0),
('1', '2918', 4.0),
('1', '1035', 5.0),
('1', '2791', 4.0),
('1', '2687', 3.0),
('1', '2018', 4.0),
('1', '3105', 5.0),
('1', '2797', 4.0),
('1', '2321', 3.0),
('1', '720', 3.0),
('1', '1270', 5.0),
('1', '527', 5.0),
('1', '2340', 3.0),
('1', '48', 5.0),
('1', '1097', 4.0),
('1', '1721', 4.0),
('1', '1545', 4.0),
('1', '745', 3.0),
('1', '2294', 4.0),
('1', '3186', 4.0),
('1', '1566', 4.0),
('1', '588', 4.0),
('1', '1907', 4.0),
('1', '783', 4.0),
('1', '1836', 5.0),
('1', '1022', 5.0),
('1', '2762', 4.0),
('1', '150', 5.0),
('1', '1', 5.0),
('1', '1961', 5.0),
('1', '1962', 4.0),
('1', '2692', 4.0),
('1', '260', 4.0),
('1', '1028', 5.0),
('1', '1029', 5.0),
('1', '1207', 4.0),
('1', '2028', 5.0),
('1', '531', 4.0),
('1', '3114', 4.0),
('1', '608', 4.0),
('1', '1246', 4.0)]
pred = algo1.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
# Out:
# (1, 1193) : predicted = 4.50 (true = 5.00)
# (1, 661) : predicted = 3.50 (true = 3.00)
# (1, 914) : predicted = 4.18 (true = 3.00)
# (1, 3408) : predicted = 4.16 (true = 4.00)
# (1, 2355) : predicted = 3.84 (true = 5.00)
# (1, 1197) : predicted = 4.04 (true = 3.00)
# (1, 1287) : predicted = 4.38 (true = 5.00)
# (1, 2804) : predicted = 4.33 (true = 5.00)
# (1, 594) : predicted = 3.90 (true = 4.00)
# (1, 919) : predicted = 4.67 (true = 4.00)
# (1, 595) : predicted = 4.02 (true = 5.00)
# (1, 938) : predicted = 3.44 (true = 4.00)
# (1, 2398) : predicted = 3.84 (true = 4.00)
# (1, 2918) : predicted = 3.95 (true = 4.00)
# (1, 1035) : predicted = 3.92 (true = 5.00)
# (1, 2791) : predicted = 4.03 (true = 4.00)
# (1, 2687) : predicted = 3.69 (true = 3.00)
# (1, 2018) : predicted = 4.02 (true = 4.00)
# (1, 3105) : predicted = 3.79 (true = 5.00)
# (1, 2797) : predicted = 4.03 (true = 4.00)
# (1, 2321) : predicted = 3.54 (true = 3.00)
# (1, 720) : predicted = 4.31 (true = 3.00)
# ...

# %%
from surprise import accuracy
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# RMSE: 0.7718
# MAE:  0.6338
# (0.77176650556311299, 0.63377859923412228)

# %%
from surprise import SVD
algo2 = SVD (n_factors=4, n_epochs=100, random_state=1)
trainSet = data.build_full_trainset()
algo2.fit(trainSet)

# %%
pred = algo2.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
# Out:
# (1, 1193) : predicted = 4.35 (true = 5.00)
# (1, 661) : predicted = 3.51 (true = 3.00)
# (1, 914) : predicted = 4.47 (true = 3.00)
# (1, 3408) : predicted = 4.34 (true = 4.00)
# (1, 2355) : predicted = 4.23 (true = 5.00)
# (1, 1197) : predicted = 4.51 (true = 3.00)
# (1, 1287) : predicted = 4.35 (true = 5.00)
# (1, 2804) : predicted = 4.43 (true = 5.00)
# (1, 594) : predicted = 4.25 (true = 4.00)
# (1, 919) : predicted = 4.57 (true = 4.00)
# (1, 595) : predicted = 4.39 (true = 5.00)
# (1, 938) : predicted = 3.92 (true = 4.00)
# (1, 2398) : predicted = 4.37 (true = 4.00)
# (1, 2918) : predicted = 4.18 (true = 4.00)
# (1, 1035) : predicted = 4.56 (true = 5.00)
# (1, 2791) : predicted = 3.93 (true = 4.00)
# (1, 2687) : predicted = 4.14 (true = 3.00)
# (1, 2018) : predicted = 4.19 (true = 4.00)
# (1, 3105) : predicted = 4.10 (true = 5.00)
# (1, 2797) : predicted = 4.26 (true = 4.00)
# (1, 2321) : predicted = 3.84 (true = 3.00)
# (1, 720) : predicted = 4.47 (true = 3.00)
# ...

# %%
from surprise import accuracy
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# RMSE: 0.7210
# MAE:  0.5755
# (0.72104238244962637, 0.57554319791169672)

# %%
from surprise import KNNBasic
algo3 = SVD (n_factors=4, n_epochs=100, random_state=1)
trainSet = data.build_full_trainset()
algo3.fit(trainSet)

# %%
pred = algo3.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
# Out:
# (1, 1193) : predicted = 4.35 (true = 5.00)
# (1, 661) : predicted = 3.51 (true = 3.00)
# (1, 914) : predicted = 4.47 (true = 3.00)
# (1, 3408) : predicted = 4.34 (true = 4.00)
# (1, 2355) : predicted = 4.23 (true = 5.00)
# (1, 1197) : predicted = 4.51 (true = 3.00)
# (1, 1287) : predicted = 4.35 (true = 5.00)
# (1, 2804) : predicted = 4.43 (true = 5.00)
# (1, 594) : predicted = 4.25 (true = 4.00)
# (1, 919) : predicted = 4.57 (true = 4.00)
# (1, 595) : predicted = 4.39 (true = 5.00)
# (1, 938) : predicted = 3.92 (true = 4.00)
# (1, 2398) : predicted = 4.37 (true = 4.00)
# (1, 2918) : predicted = 4.18 (true = 4.00)
# (1, 1035) : predicted = 4.56 (true = 5.00)
# (1, 2791) : predicted = 3.93 (true = 4.00)
# (1, 2687) : predicted = 4.14 (true = 3.00)
# (1, 2018) : predicted = 4.19 (true = 4.00)
# (1, 3105) : predicted = 4.10 (true = 5.00)
# (1, 2797) : predicted = 4.26 (true = 4.00)
# (1, 2321) : predicted = 3.84 (true = 3.00)
# (1, 720) : predicted = 4.47 (true = 3.00)
# ...

# %%
from surprise import accuracy
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# RMSE: 0.7210
# MAE:  0.5755
# (0.72104238244962637, 0.57554319791169672)

# %%
testset =[('3', '3421', 4.0),
('3', '1641', 2.0),
('3', '648', 3.0),
('3', '1394', 4.0),
('3', '3534', 3.0),
('3', '104', 4.0),
('3', '2735', 4.0),
('3', '1210', 4.0),
('3', '1431', 3.0),
('3', '3868', 3.0),
('3', '1079', 5.0),
('3', '2997', 3.0),
('3', '1615', 5.0),
('3', '1291', 4.0),
('3', '1259', 5.0),
('3', '653', 4.0),
('3', '2167', 5.0),
('3', '1580', 3.0),
('3', '3619', 2.0),
('3', '260', 5.0),
('3', '2858', 4.0),
('3', '3114', 3.0),
('3', '1049', 4.0),
('3', '1261', 1.0),
('3', '552', 4.0),
('3', '480', 4.0),
('3', '1265', 2.0),
('3', '1266', 5.0),
('3', '733', 5.0),
('3', '1196', 4.0),
('3', '590', 4.0),
('3', '2355', 5.0),
('3', '1197', 5.0),
('3', '1198', 5.0),
('3', '1378', 5.0),
('3', '593', 3.0),
('3', '1379', 4.0),
('3', '3552', 5.0),
('3', '1304', 5.0),
('3', '1270', 3.0),
('3', '2470', 4.0),
('3', '3168', 4.0),
('3', '2617', 2.0),
('3', '1961', 4.0),
('3', '3671', 5.0),
('3', '2006', 4.0),
('3', '2871', 4.0),
('3', '2115', 4.0),
('3', '1968', 4.0),
('3', '1136', 5.0),
('3', '2081', 4.0)]
pred = algo1.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# (3, 3421) : predicted = 3.82 (true = 4.00)
# (3, 1641) : predicted = 3.81 (true = 2.00)
# (3, 648) : predicted = 3.52 (true = 3.00)
# (3, 1394) : predicted = 3.71 (true = 4.00)
# (3, 3534) : predicted = 3.24 (true = 3.00)
# (3, 104) : predicted = 3.59 (true = 4.00)
# (3, 2735) : predicted = 3.10 (true = 4.00)
# (3, 1210) : predicted = 3.93 (true = 4.00)
# (3, 1431) : predicted = 2.68 (true = 3.00)
# (3, 3868) : predicted = 3.62 (true = 3.00)
# (3, 1079) : predicted = 4.07 (true = 5.00)
# (3, 2997) : predicted = 3.89 (true = 3.00)
# (3, 1615) : predicted = 3.54 (true = 5.00)
# (3, 1291) : predicted = 4.13 (true = 4.00)
# (3, 1259) : predicted = 4.07 (true = 5.00)
# (3, 653) : predicted = 3.41 (true = 4.00)
# (3, 2167) : predicted = 3.40 (true = 5.00)
# (3, 1580) : predicted = 3.65 (true = 3.00)
# (3, 3619) : predicted = 3.17 (true = 2.00)
# (3, 260) : predicted = 4.32 (true = 5.00)
# (3, 2858) : predicted = 4.13 (true = 4.00)
# (3, 3114) : predicted = 4.01 (true = 3.00)
# ...

# %%
pred = algo2.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# (3, 3421) : predicted = 3.98 (true = 4.00)
# (3, 1641) : predicted = 3.82 (true = 2.00)
# (3, 648) : predicted = 4.02 (true = 3.00)
# (3, 1394) : predicted = 3.55 (true = 4.00)
# (3, 3534) : predicted = 3.49 (true = 3.00)
# (3, 104) : predicted = 4.06 (true = 4.00)
# (3, 2735) : predicted = 3.53 (true = 4.00)
# (3, 1210) : predicted = 4.31 (true = 4.00)
# (3, 1431) : predicted = 3.06 (true = 3.00)
# (3, 3868) : predicted = 3.54 (true = 3.00)
# (3, 1079) : predicted = 3.75 (true = 5.00)
# (3, 2997) : predicted = 3.62 (true = 3.00)
# (3, 1615) : predicted = 4.08 (true = 5.00)
# (3, 1291) : predicted = 4.38 (true = 4.00)
# (3, 1259) : predicted = 4.10 (true = 5.00)
# (3, 653) : predicted = 3.73 (true = 4.00)
# (3, 2167) : predicted = 3.73 (true = 5.00)
# (3, 1580) : predicted = 4.03 (true = 3.00)
# (3, 3619) : predicted = 3.40 (true = 2.00)
# (3, 260) : predicted = 4.48 (true = 5.00)
# (3, 2858) : predicted = 4.24 (true = 4.00)
# (3, 3114) : predicted = 4.04 (true = 3.00)
# ...

# %%
pred = algo3.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# (3, 3421) : predicted = 3.98 (true = 4.00)
# (3, 1641) : predicted = 3.82 (true = 2.00)
# (3, 648) : predicted = 4.02 (true = 3.00)
# (3, 1394) : predicted = 3.55 (true = 4.00)
# (3, 3534) : predicted = 3.49 (true = 3.00)
# (3, 104) : predicted = 4.06 (true = 4.00)
# (3, 2735) : predicted = 3.53 (true = 4.00)
# (3, 1210) : predicted = 4.31 (true = 4.00)
# (3, 1431) : predicted = 3.06 (true = 3.00)
# (3, 3868) : predicted = 3.54 (true = 3.00)
# (3, 1079) : predicted = 3.75 (true = 5.00)
# (3, 2997) : predicted = 3.62 (true = 3.00)
# (3, 1615) : predicted = 4.08 (true = 5.00)
# (3, 1291) : predicted = 4.38 (true = 4.00)
# (3, 1259) : predicted = 4.10 (true = 5.00)
# (3, 653) : predicted = 3.73 (true = 4.00)
# (3, 2167) : predicted = 3.73 (true = 5.00)
# (3, 1580) : predicted = 4.03 (true = 3.00)
# (3, 3619) : predicted = 3.40 (true = 2.00)
# (3, 260) : predicted = 4.48 (true = 5.00)
# (3, 2858) : predicted = 4.24 (true = 4.00)
# (3, 3114) : predicted = 4.04 (true = 3.00)
# ...

# %%
testset = [('6', '2406', 5.0),
('6', '1101', 4.0),
('6', '3717', 4.0),
('6', '1030', 4.0),
('6', '1688', 5.0),
('6', '1035', 5.0),
('6', '3578', 4.0),
('6', '364', 4.0),
('6', '3501', 5.0),
('6', '3072', 4.0),
('6', '368', 4.0),
('6', '296', 2.0),
('6', '48', 5.0),
('6', '3074', 5.0),
('6', '1188', 4.0),
('6', '3508', 3.0),
('6', '588', 4.0),
('6', '1', 4.0),
('6', '1043', 4.0),
('6', '2858', 1.0),
('6', '377', 3.0),
('6', '590', 3.0),
('6', '595', 4.0),
('6', '597', 5.0),
('6', '383', 4.0),
('6', '2506', 3.0),
('6', '3524', 3.0),
('6', '1566', 4.0),
('6', '1569', 4.0),
('6', '2006', 4.0),
('6', '2081', 4.0),
('6', '2082', 3.0),
('6', '3600', 3.0),
('6', '3604', 5.0),
('6', '2802', 4.0),
('6', '3534', 4.0),
('6', '3536', 5.0),
('6', '1210', 3.0),
('6', '3753', 5.0),
('6', '3682', 3.0),
('6', '2017', 3.0),
('6', '3685', 3.0),
('6', '3610', 3.0),
('6', '1296', 3.0),
('6', '838', 4.0),
('6', '1007', 3.0),
('6', '1947', 5.0),
('6', '2966', 5.0),
('6', '266', 4.0),
('6', '17', 4.0),
('6', '3699', 4.0),
('6', '1441', 4.0),
('6', '1088', 5.0),
('6', '912', 4.0),
('6', '199', 5.0),
('6', '914', 5.0),
('6', '3408', 5.0),
('6', '1806', 3.0),
('6', '3624', 4.0),
('6', '2469', 3.0),
('6', '2396', 4.0),
('6', '2100', 3.0),
('6', '1959', 3.0),
('6', '2321', 3.0),
('6', '1380', 5.0),
('6', '920', 4.0),
('6', '569', 4.0),
('6', '1674', 4.0),
('6', '3565', 4.0),
('6', '1028', 4.0),
('6', '34', 4.0)]
pred = algo1.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# (6, 2406) : predicted = 3.77 (true = 5.00)
# (6, 1101) : predicted = 3.85 (true = 4.00)
# (6, 3717) : predicted = 3.04 (true = 4.00)
# (6, 1030) : predicted = 3.27 (true = 4.00)
# (6, 1688) : predicted = 3.78 (true = 5.00)
# (6, 1035) : predicted = 4.38 (true = 5.00)
# (6, 3578) : predicted = 4.23 (true = 4.00)
# (6, 364) : predicted = 3.98 (true = 4.00)
# (6, 3501) : predicted = 3.91 (true = 5.00)
# (6, 3072) : predicted = 3.82 (true = 4.00)
# (6, 368) : predicted = 3.75 (true = 4.00)
# (6, 296) : predicted = 3.99 (true = 2.00)
# (6, 48) : predicted = 3.18 (true = 5.00)
# (6, 3074) : predicted = 3.80 (true = 5.00)
# (6, 1188) : predicted = 3.96 (true = 4.00)
# (6, 3508) : predicted = 4.17 (true = 3.00)
# (6, 588) : predicted = 3.82 (true = 4.00)
# (6, 1) : predicted = 4.07 (true = 4.00)
# (6, 1043) : predicted = 3.06 (true = 4.00)
# (6, 2858) : predicted = 4.17 (true = 1.00)
# (6, 377) : predicted = 3.57 (true = 3.00)
# (6, 590) : predicted = 4.02 (true = 3.00)
# ...

# %%
pred = algo2.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# (6, 2406) : predicted = 4.07 (true = 5.00)
# (6, 1101) : predicted = 4.18 (true = 4.00)
# (6, 3717) : predicted = 3.66 (true = 4.00)
# (6, 1030) : predicted = 3.68 (true = 4.00)
# (6, 1688) : predicted = 4.37 (true = 5.00)
# (6, 1035) : predicted = 4.88 (true = 5.00)
# (6, 3578) : predicted = 3.92 (true = 4.00)
# (6, 364) : predicted = 4.08 (true = 4.00)
# (6, 3501) : predicted = 4.22 (true = 5.00)
# (6, 3072) : predicted = 4.08 (true = 4.00)
# (6, 368) : predicted = 3.91 (true = 4.00)
# (6, 296) : predicted = 2.35 (true = 2.00)
# (6, 48) : predicted = 3.89 (true = 5.00)
# (6, 3074) : predicted = 3.36 (true = 5.00)
# (6, 1188) : predicted = 4.19 (true = 4.00)
# (6, 3508) : predicted = 3.15 (true = 3.00)
# (6, 588) : predicted = 4.10 (true = 4.00)
# (6, 1) : predicted = 4.16 (true = 4.00)
# (6, 1043) : predicted = 3.67 (true = 4.00)
# (6, 2858) : predicted = 3.12 (true = 1.00)
# (6, 377) : predicted = 4.08 (true = 3.00)
# (6, 590) : predicted = 3.89 (true = 3.00)
# ...

# %%
pred = algo3.test(testset)
for (uid,iid,r_ui,est,details) in pred:
    print('(%s, %s) : predicted = %.2f (true = %.2f)' % (uid, iid, est, r_ui))
accuracy.rmse(pred) , accuracy.mae(pred)
# Out:
# (6, 2406) : predicted = 4.07 (true = 5.00)
# (6, 1101) : predicted = 4.18 (true = 4.00)
# (6, 3717) : predicted = 3.66 (true = 4.00)
# (6, 1030) : predicted = 3.68 (true = 4.00)
# (6, 1688) : predicted = 4.37 (true = 5.00)
# (6, 1035) : predicted = 4.88 (true = 5.00)
# (6, 3578) : predicted = 3.92 (true = 4.00)
# (6, 364) : predicted = 4.08 (true = 4.00)
# (6, 3501) : predicted = 4.22 (true = 5.00)
# (6, 3072) : predicted = 4.08 (true = 4.00)
# (6, 368) : predicted = 3.91 (true = 4.00)
# (6, 296) : predicted = 2.35 (true = 2.00)
# (6, 48) : predicted = 3.89 (true = 5.00)
# (6, 3074) : predicted = 3.36 (true = 5.00)
# (6, 1188) : predicted = 4.19 (true = 4.00)
# (6, 3508) : predicted = 3.15 (true = 3.00)
# (6, 588) : predicted = 4.10 (true = 4.00)
# (6, 1) : predicted = 4.16 (true = 4.00)
# (6, 1043) : predicted = 3.67 (true = 4.00)
# (6, 2858) : predicted = 3.12 (true = 1.00)
# (6, 377) : predicted = 4.08 (true = 3.00)
# (6, 590) : predicted = 3.89 (true = 3.00)
# ...
